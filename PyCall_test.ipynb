# %%
using PyCall

torch = pyimport("torch")
torchvision = pyimport("torchvision")
models = torchvision.models
transforms = torchvision.transforms
PIL = pyimport("PIL")
plt = pyimport("matplotlib.pyplot")
# Out:
# PyObject <module 'matplotlib.pyplot' from '/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
# PyTorchのバージョン確認
println("PyTorch Version: $(torch.__version__)")
println("Torchvision Version: $(torchvision.__version__)")
# Out:
# PyTorch Version: 1.1.0
# Torchvision Version: 0.3.0

# %%
# 学習済みVGG-16モデルロード
## 初回実行時は、学習済みパラメータのダウンロードに時間がかかる
net = models.vgg16(pretrained=true)
net.eval() # 推論モードに設定

# モデルのネットワーク構成確認
println(net)
# Out:
#  38%|████████▊              | 211238912/553433881 [01:26<02:19, 2453837.96it/s]Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /home/user/.cache/torch/checkpoints/vgg16-397923af.pth
#  33%|███████▌               | 182960128/553433881 [01:20<02:36, 2365023.70it/s]
# PyError ($(Expr(:escape, :(ccall(#= /home/user/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:44 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'BlockingIOError'>
# BlockingIOError(11, 'write could not complete without blocking', 0)
#   File "/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torchvision/models/vgg.py", line 144, in vgg16
#     return _vgg('vgg16', 'D', False, pretrained, progress, **kwargs)
#   File "/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torchvision/models/vgg.py", line 92, in _vgg
#     progress=progress)
#   File "/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/hub.py", line 433, in load_state_dict_from_url
#     _download_url_to_file(url, cached_file, hash_prefix, progress=progress)
#   File "/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/torch/hub.py", line 370, in _download_url_to_file
#     pbar.update(len(buffer))
#   File "/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/tqdm/_tqdm.py", line 885, in __exit__
#     self.close()
#   File "/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/tqdm/_tqdm.py", line 1120, in close
#     self.sp(self.__repr__())
#   File "/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/tqdm/_tqdm.py", line 193, in print_status
#     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#   File "/home/user/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/tqdm/_tqdm.py", line 187, in fp_write
#     fp_flush()
#
#
# Stacktrace:
#  [1] pyerr_check at /home/user/.julia/packages/PyCall/ttONZ/src/exception.jl:60 [inlined]
#  [2] pyerr_check at /home/user/.julia/packages/PyCall/ttONZ/src/exception.jl:64 [inlined]
#  [3] macro expansion at /home/user/.julia/packages/PyCall/ttONZ/src/exception.jl:84 [inlined]
#  [4] __pycall!(::PyObject, ::Ptr{PyCall.PyObject_struct}, ::PyObject, ::PyObject) at /home/user/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:44
#  [5] _pycall!(::PyObject, ::PyObject, ::Tuple{}, ::Int64, ::PyObject) at /home/user/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:29
#  [6] _pycall!(::PyObject, ::PyObject, ::Tuple{}, ::Base.Iterators.Pairs{Symbol,Bool,Tuple{Symbol},NamedTuple{(:pretrained,),Tuple{Bool}}}) at /home/user/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:11
#  [7] #call#111 at /home/user/.julia/packages/PyCall/ttONZ/src/pyfncall.jl:89 [inlined]
#  [8] (::getfield(PyCall, Symbol("#kw#PyObject")))(::NamedTuple{(:pretrained,),Tuple{Bool}}, ::PyObject) at ./none:0
#  [9] top-level scope at In[6]:1
